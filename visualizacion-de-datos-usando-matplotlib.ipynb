# %% [markdown]
# LAB: Visualización de datos usando Matplotlib
# ==========================================

# %%
## inicialización
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas
import matplotlib.lines as mlines
# %matplotlib inline

# %% [markdown]
# ## Punto 1

# %% [markdown]
# Construya una gráfica similar a la siguiente usando el archivo `indicadores-mundiales.csv`. Se grafica la suma del porcetaje de la población por regiones.
#
# ![act2](images/suma-pob-region-edades-2.png)

# %%
import matplotlib.pyplot as plt
y = np.arange(6)

df = pandas.read_csv('indicadores-mundiales.csv',sep=',', encoding='latin-1')
Region_Grupo=df[['Region', 'Poblacion 0-14','Poblacion 15-64','Poblacion 65+']]
Region_Grupo = Region_Grupo.groupby('Region').sum()[['Poblacion 0-14', 'Poblacion 15-64', 'Poblacion 65+']]/100

plt.plot(X + 0.00,Region_Grupo['Poblacion 0-14'], 'ro', color = 'b')
plt.plot(X + 0.25,Region_Grupo['Poblacion 15-64'], 'ro', color = 'g')
plt.plot(X + 0.50,Region_Grupo['Poblacion 65+'], 'ro', color = 'r')
#fig.suptitle("Regiones")
plt.xticks(X + 0.2, ['Africa','Asia','Europa','Las Americas','Oceania','Oriente Medio'])
plt.xlabel('Region')
plt.ylabel('Valor')
green_line = mlines.Line2D([], [], color='green', label='Población 0 a 14 ')
blue_line = mlines.Line2D([], [], color='blue', label='Población 15 a 64')
red_line = mlines.Line2D([], [], color='red', label='Población 65+')
plt.legend(handles=[blue_line, red_line,green_line])

# %%
df = pandas.read_csv('indicadores-mundiales.csv',sep=',', encoding='latin-1')
Region_Grupo=df[['Region', 'Poblacion 0-14','Poblacion 15-64','Poblacion 65+']]
Region_Grupo = Region_Grupo.groupby('Region').sum()[['Poblacion 0-14', 'Poblacion 15-64', 'Poblacion 65+']]/100
print(Region_Grupo)
# Out:
#                Poblacion 0-14  Poblacion 15-64  Poblacion 65+
# Region
# Asia                   53.186          106.687         10.130
# Europa                 37.802          138.306         28.905
# Las Americas           53.755          109.018         12.231
# Oceania                17.848           31.331          2.825
# Oriente Medio          17.547           32.511          1.942
# africa                111.362          144.527          9.117

# %% [markdown]
# ## Punto 2
#
# Construya una gráfica similar a la siguiente usando el archivo `indicadores-mundiales.csv`. Se grafica la suma del porcetaje de la población por regiones.
#
# ![act2](images/suma-pob-region-edades-3.png)

# %%
df = pandas.read_csv('indicadores-mundiales.csv',sep=',', encoding='latin-1')
Region_Grupo=df[['Region', 'Poblacion 0-14','Poblacion 15-64','Poblacion 65+']]
Region_Grupo = Region_Grupo.groupby('Region').sum()[['Poblacion 0-14', 'Poblacion 15-64', 'Poblacion 65+']]/100

X = np.arange(6)
plt.bar(X + 0.00, Region_Grupo['Poblacion 0-14'], color = "b", width = 0.25)
plt.bar(X + 0.25, Region_Grupo['Poblacion 15-64'], color = "g", width = 0.25)
plt.bar(X + 0.50, Region_Grupo['Poblacion 65+'], color = "r", width = 0.25)
plt.xticks(X + 0.2, ['Africa','Asia','Europa','Las Americas','Oceania','Oriente Medio'])
plt.xlabel('Region')
plt.ylabel('Valor')
green_line = mlines.Line2D([], [], color='green', label='Población 0 a 14 ')
blue_line = mlines.Line2D([], [], color='blue', label='Población 15 a 64')
red_line = mlines.Line2D([], [], color='red', label='Población 65+')
plt.legend(handles=[blue_line, red_line,green_line])

# %%
df = pandas.read_csv('indicadores-mundiales.csv',sep=',', encoding='latin-1')
Region_Grupo=df[['Region', 'Poblacion 0-14','Poblacion 15-64','Poblacion 65+']]
Region_Grupo = Region_Grupo.groupby('Region').sum()[['Poblacion 0-14', 'Poblacion 15-64', 'Poblacion 65+']]/100

fig, axs = plt.subplots(sharex='col', sharey='row', figsize=(15, 6));
plt.subplots_adjust( wspace = 0.00, hspace=0.00)
fig.suptitle("Región")
colors=['blue','orange','green']
paso=[0,.25,0.5]
X = np.arange(6)
for index, colname in enumerate(Region_Grupo.columns):
    plt.bar(X + paso[index], Region_Grupo[colname], color = colors[index], width = 0.25)
    plt.xticks(X + 0.2, ['Africa','Asia','Europa','Las Americas','Oceania','Oriente Medio'])
green_line = mlines.Line2D([], [], color='green', label='Población 0 a 14 ')
blue_line = mlines.Line2D([], [], color='blue', label='Población 15 a 64')
red_line = mlines.Line2D([], [], color='red', label='Población 65+')
plt.legend(handles=[blue_line, red_line,green_line])
    
    
   # axs[index].set_xticklabels(list(Region_Grupo.index) ,rotation = 90, ha='center')
  #  axs[index].set_title(list(Region_Grupo.columns)[index])
    
    
    
#    plt.xlabel('Region')
 #   plt.ylabel('Valor')


#    axs[index].bar(list(Region_Grupo.index), Region_Grupo[colname], color=colors[index])
#    axs[index].text(-2.5, int(max(list(Region_Grupo[colname])) / 2), s=colname)
#    axs[index].set_ylabel('Valor')

# %% [markdown]
# ## Punto 3
# Construya una gráfica similar a la siguiente usando el archivo `indicadores-mundiales.csv`. Se grafica la suma del porcetaje de la población por regiones.
#
# ![act3](images/suma-pob-region-edades-4.png)

# %%
df = pandas.read_csv('indicadores-mundiales.csv',sep=',', encoding='latin-1')
Region_Grupo=df[['Region', 'Poblacion 0-14','Poblacion 15-64','Poblacion 65+']]
Region_Grupo = Region_Grupo.groupby('Region').sum()[['Poblacion 0-14', 'Poblacion 15-64', 'Poblacion 65+']]/100
fig, axs = plt.subplots(3, figsize=(10, 10), sharex=True);
plt.subplots_adjust(wspace = 0.00, hspace=0.1)
fig.suptitle("Región")
colors=['blue','orange','green']
for index, colname in enumerate(Region_Grupo.columns):
    axs[index].bar(list(Region_Grupo.index), Region_Grupo[colname], color=colors[index])
    axs[index].text(-2.5, int(max(list(Region_Grupo[colname])) / 2), s=colname)
    axs[index].set_ylabel('Valor')

# %% [markdown]
# ## Punto 4
#
# Construya una gráfica similar a la siguiente usando el archivo `indicadores-mundiales.csv`. Promedio de gastos per capita por año.
#
# ![act4](images/prom-gastos-salud-per-capita-ano.png)

# %% [markdown]
# ## Punto 5
#
# Construya una gráfica similar a la siguiente usando el archivo `indicadores-mundiales.csv`. Promedio de gastos per capita por año.
#
# ![act5](images/prom-region-edades-ano.png)

# %% [markdown]
# ---
